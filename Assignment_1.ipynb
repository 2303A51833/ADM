# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51833/ADM/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df=pd.read_csv('/content/employee_data.csv')
print(df)
# Out:
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
df.describe()
# Out:
#        Employee_ID        Age         Salary  Job_Satisfaction  \
# count     50.00000  45.000000      45.000000         40.000000
# mean    1025.50000  39.177778   72349.200000          5.550000
# std       14.57738  10.869659   26170.218818          2.726414
# min     1001.00000  23.000000   31016.000000          1.000000
# 25%     1013.25000  30.000000   52662.000000          3.000000
# 50%     1025.50000  39.000000   70757.000000          6.000000
# 75%     1037.75000  47.000000   92592.000000          7.000000
# max     1050.00000  59.000000  119812.000000         10.000000
#
#        Work_Hours_Per_Week
# count            50.000000
# mean             44.720000
# std               9.722769
# min              30.000000
# 25%              36.000000
# 50%              46.000000
# 75%              53.750000
# max              59.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          50 non-null     int64
#  1   Age                  45 non-null     float64
#  2   Salary               45 non-null     float64
#  3   Job_Satisfaction     40 non-null     float64
#  4   Work_Hours_Per_Week  50 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 2.1 KB

# %%
df.isnull().sum()
# Out:
# Employee_ID             0
# Age                     5
# Salary                  5
# Job_Satisfaction       10
# Work_Hours_Per_Week     0
# dtype: int64

# %%
df.isna()
# Out:
#     Employee_ID    Age  Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0         False  False   False             False                False
# 1         False  False   False             False                False
# 2         False  False   False             False                False
# 3         False  False   False             False                False
# 4         False  False   False             False                False
# 5         False  False   False             False                False
# 6         False  False    True              True                False
# 7         False  False   False             False                False
# 8         False  False   False             False                False
# 9         False  False    True             False                False
# 10        False  False   False             False                False
# 11        False   True   False              True                False
# ...

# %%
df['Job_Satisfaction'].mean()
# Out:
# 5.55

# %%
df['Work_Hours_Per_Week'].mean()
# Out:
# 44.72

# %%
df['Age'].mean()
# Out:
# 39.17777777777778

# %%
df['Salary'].mean()
# Out:
# 72349.2

# %%
df['Job_Satisfaction'].median()
# Out:
# 6.0

# %%
df['Work_Hours_Per_Week'].median()
# Out:
# 46.0

# %%
df['Age'].median()
# Out:
# 39.0

# %%
df['Salary'].median()
# Out:
# 70757.0

# %%
df['Job_Satisfaction'].mode()
# Out:
# 0    7.0
# Name: Job_Satisfaction, dtype: float64

# %%
df['Work_Hours_Per_Week'].mode()
# Out:
# 0    46
# Name: Work_Hours_Per_Week, dtype: int64

# %%
df['Age'].mode()
# Out:
# 0    23.0
# Name: Age, dtype: float64

# %%
df['Salary'].mode()
# Out:
# 0      31016.0
# 1      32568.0
# 2      32695.0
# 3      33561.0
# 4      35258.0
# 5      39268.0
# 6      39692.0
# 7      41534.0
# 8      42185.0
# 9      42666.0
# 10     43986.0
# 11     52662.0
# 12     53247.0
# 13     54300.0
# 14     56854.0
# 15     63159.0
# 16     67065.0
# 17     68044.0
# 18     68660.0
# 19     69099.0
# 20     69504.0
# 21     70397.0
# 22     70757.0
# 23     70774.0
# 24     75758.0
# 25     78190.0
# 26     78984.0
# 27     81214.0
# 28     82251.0
# 29     82995.0
# 30     85591.0
# 31     91228.0
# 32     91858.0
# 33     92592.0
# 34     93704.0
# 35     94505.0
# 36     95697.0
# 37     97563.0
# 38    102409.0
# 39    104065.0
# 40    108953.0
# 41    112798.0
# 42    116807.0
# 43    119789.0
# 44    119812.0
# Name: Salary, dtype: float64

# %%
df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean(), inplace=True)
# Out:
# <ipython-input-28-69ada0b06065>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean(), inplace=True)

# %%
df['Job_Satisfaction'] = df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean())

# %%
df['Work_Hours_Per_Week'] =df['Work_Hours_Per_Week'].fillna(df['Work_Hours_Per_Week'].mean())

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df
# Out:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0              9.00                   36
# 1          1002  36.000000   82995.0              8.00                   59
# 2          1003  29.000000   70757.0              2.00                   30
# 3          1004  42.000000   39692.0              1.00                   30
# 4          1005  40.000000   75758.0              7.00                   54
# 5          1006  44.000000  102409.0              7.00                   56
# 6          1007  32.000000   72349.2              5.55                   59
# 7          1008  32.000000   95697.0              5.00                   54
# 8          1009  45.000000   67065.0              3.00                   49
# 9          1010  57.000000   72349.2              8.00                   42
# 10         1011  45.000000   41534.0              6.00                   38
# ...

# %%
df['Work_Hours_Per_Week'].fillna(df['Work_Hours_Per_Week'].mean(),inplace=True)
# Out:
# <ipython-input-34-635897f150a3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Work_Hours_Per_Week'].fillna(df['Work_Hours_Per_Week'].mean(),inplace=True)

# %%
print("Dataset after handling missing values:")
print(df)
# Out:
# Dataset after handling missing values:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0              9.00                   36
# 1          1002  36.000000   82995.0              8.00                   59
# 2          1003  29.000000   70757.0              2.00                   30
# 3          1004  42.000000   39692.0              1.00                   30
# 4          1005  40.000000   75758.0              7.00                   54
# 5          1006  44.000000  102409.0              7.00                   56
# 6          1007  32.000000   72349.2              5.55                   59
# 7          1008  32.000000   95697.0              5.00                   54
# 8          1009  45.000000   67065.0              3.00                   49
# 9          1010  57.000000   72349.2              8.00                   42
# 10         1011  45.000000   41534.0              6.00                   38
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df[['Age', 'Salary']] = scaler.fit_transform(df[['Age', 'Salary']])

# %%
df[['Job_Satisfaction']] =scaler.fit_transform(df[[ 'Job_Satisfaction']])

# %%
df['Job_Satisfaction']
# Out:
# 0     0.888889
# 1     0.777778
# 2     0.111111
# 3     0.000000
# 4     0.666667
# 5     0.666667
# 6     0.505556
# 7     0.444444
# 8     0.222222
# 9     0.777778
# 10    0.555556
# 11    0.505556
# 12    0.505556
# 13    0.000000
# 14    0.222222
# 15    0.444444
# 16    0.222222
# 17    0.000000
# 18    0.444444
# 19    1.000000
# 20    0.666667
# 21    0.666667
# 22    0.505556
# 23    0.888889
# 24    1.000000
# 25    0.505556
# 26    0.222222
# 27    0.666667
# 28    0.000000
# 29    0.333333
# 30    0.333333
# 31    0.505556
# 32    0.666667
# 33    0.666667
# 34    0.505556
# 35    0.333333
# 36    0.666667
# 37    0.505556
# 38    0.222222
# 39    0.555556
# 40    0.111111
# 41    1.000000
# 42    0.888889
# 43    0.444444
# 44    0.555556
# 45    0.333333
# 46    0.505556
# 47    0.505556
# 48    0.666667
# 49    0.888889
# Name: Job_Satisfaction, dtype: float64

# %%
df[['Work_Hours_Per_Week']] = scaler.fit_transform(df[[ 'Work_Hours_Per_Week']])

# %%
df['Work_Hours_Per_Week']
# Out:
# 0     0.206897
# 1     1.000000
# 2     0.000000
# 3     0.000000
# 4     0.827586
# 5     0.896552
# 6     1.000000
# 7     0.827586
# 8     0.655172
# 9     0.413793
# 10    0.275862
# 11    0.068966
# 12    0.206897
# 13    0.172414
# 14    0.241379
# 15    0.896552
# 16    0.275862
# 17    1.000000
# 18    0.137931
# 19    0.000000
# 20    0.620690
# 21    0.310345
# 22    0.379310
# 23    0.793103
# 24    0.482759
# 25    0.896552
# 26    0.724138
# 27    0.793103
# 28    0.275862
# 29    0.655172
# 30    0.551724
# 31    1.000000
# 32    0.551724
# 33    0.862069
# 34    0.655172
# 35    0.379310
# 36    1.000000
# 37    0.206897
# 38    0.034483
# 39    0.068966
# 40    0.551724
# 41    0.137931
# 42    0.551724
# 43    0.793103
# 44    0.551724
# 45    0.896552
# 46    0.551724
# 47    0.034483
# 48    0.034483
# 49    0.931034
# Name: Work_Hours_Per_Week, dtype: float64

# %%
df['Work_Hours_Per_Week'] = (df['Work_Hours_Per_Week'] - df['Work_Hours_Per_Week'].mean()) / df['Work_Hours_Per_Week'].std()

# %%
df
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708          0.888889            -0.896864
# 1          1002  0.361111  0.585375          0.777778             1.468717
# 2          1003  0.166667  0.447554          0.111111            -1.513972
# 3          1004  0.527778  0.097707          0.000000            -1.513972
# 4          1005  0.472222  0.503874          0.666667             0.954461
# 5          1006  0.583333  0.804011          0.666667             1.160163
# 6          1007  0.250000  0.465485          0.505556             1.468717
# 7          1008  0.250000  0.728422          0.444444             0.954461
# 8          1009  0.611111  0.405975          0.222222             0.440204
# 9          1010  0.944444  0.465485          0.777778            -0.279756
# 10         1011  0.611111  0.118451          0.555556            -0.691161
# ...
