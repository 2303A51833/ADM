# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51833/ADM/blob/main/Lab4_Winedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/wine_data.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         21000 non-null  float64
#  1   volatile_acidity      21000 non-null  float64
#  2   citric_acid           21000 non-null  float64
#  3   residual_sugar        21000 non-null  float64
#  4   chlorides             21000 non-null  float64
#  5   free_sulfur_dioxide   21000 non-null  float64
#  6   total_sulfur_dioxide  21000 non-null  float64
#  7   density               21000 non-null  float64
#  8   pH                    21000 non-null  float64
#  9   sulphates             21000 non-null  float64
#  10  alcohol               21000 non-null  float64
#  11  quality               21000 non-null  int64
# dtypes: float64(11), int64(1)
# memory usage: 1.9 MB
# None

# %%
print(df.describe())
# Out:
#        fixed_acidity  volatile_acidity   citric_acid  residual_sugar  \
# count   21000.000000      21000.000000  21000.000000    21000.000000
# mean        9.797079          0.774796      0.793870       31.289348
# std         2.413919          0.365015      0.384833       19.015391
# min         3.800000          0.080000      0.000000        0.600000
# 25%         7.600000          0.430000      0.410000        9.800000
# 50%        10.000000          0.830000      0.870000       37.600000
# 75%        11.800000          1.080000      1.110000       46.800000
# max        15.900000          1.580000      1.660000       65.800000
#
#           chlorides  free_sulfur_dioxide  total_sulfur_dioxide       density  \
# count  21000.000000         21000.000000          21000.000000  21000.000000
# mean       0.200245           129.442333            229.008762      1.009972
# std        0.124933            77.167262            100.183265      0.012032
# ...

# %%
# One-hot encoding
encoded_data = pd.get_dummies(df, columns=['quality'], prefix='quality')


print("One-hot Encoded Data:\n", encoded_data.head())
# Out:
# One-hot Encoded Data:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0           11.6             0.580         0.66            2.20      0.074
# 1           10.4             0.610         0.49            2.10      0.200
# 2            7.4             1.185         0.00            4.25      0.097
# 3           10.4             0.440         0.42            1.50      0.145
# 4            8.3             1.020         0.02            3.40      0.084
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 10.0                  47.0  1.00080  3.25       0.57
# 1                  5.0                  16.0  0.99940  3.16       0.63
# 2                  5.0                  14.0  0.99660  3.63       0.54
# 3                 34.0                  48.0  0.99832  3.38       0.86
# 4                  6.0                  11.0  0.99892  3.48       0.49
#
# ...

# %%
# Create a derived column: sugar_density_ratio
encoded_data['sugar_density_ratio'] = encoded_data['residual_sugar'] / encoded_data['density']

print("Derived Column Data Sample:\n", encoded_data[['residual_sugar', 'density', 'sugar_density_ratio']].head())
# Out:
# Derived Column Data Sample:
#     residual_sugar  density  sugar_density_ratio
# 0            2.20  1.00080             2.198241
# 1            2.10  0.99940             2.101261
# 2            4.25  0.99660             4.264499
# 3            1.50  0.99832             1.502524
# 4            3.40  0.99892             3.403676

# %%
# Group by quality and compute mean alcohol content
grouped_data = df.groupby('quality')['alcohol'].mean().reset_index()

print("Grouped Data:\n", grouped_data)
# Out:
# Grouped Data:
#     quality    alcohol
# 0        3  11.624750
# 1        4  11.553267
# 2        5  10.371093
# 3        6  10.646033
# 4        7  11.619100
# 5        8  11.595200
# 6        9  11.632567

# %%
# Create a pivot table for average citric acid values across quality levels
pivot_table = df.pivot_table(values='citric_acid', index='quality', aggfunc='mean').reset_index()

pivot_table = df.pivot_table(values='citric_acid', index='quality', aggfunc='mean').reset_index()

print("Pivot Table:\n", pivot_table)
pivot_table
# Out:
# Pivot Table:
#     quality  citric_acid
# 0        3     1.003857
# 1        4     0.948657
# 2        5     0.514153
# 3        6     0.361420
# 4        7     0.760803
# 5        8     0.960370
# 6        9     1.007827
#    quality  citric_acid
# 0        3     1.003857
# 1        4     0.948657
# 2        5     0.514153
# 3        6     0.361420
# 4        7     0.760803
# 5        8     0.960370
# 6        9     1.007827
